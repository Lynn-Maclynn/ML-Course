# %%
import scipy
print(scipy.__version__)
# Out:
# 1.11.1

# %%
from scipy import misc
import matplotlib.pyplot as plt

ascent = misc.ascent()
plt.gray()
plt.imshow(ascent)
plt.show()
# Out:
# C:\Users\SOP TELECOM\AppData\Local\Temp\ipykernel_6620\1486159626.py:4: DeprecationWarning: scipy.misc.ascent has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.ascent instead.
#   ascent = misc.ascent()

# %%
from scipy import misc
import matplotlib.pyplot as plt

ascent = misc.ascent()

plt.axis("off") # removes the axis and the ticks
plt.gray()
plt.imshow(ascent)
plt.show()
# Out:
# C:\Users\SOP TELECOM\AppData\Local\Temp\ipykernel_6620\3646751170.py:4: DeprecationWarning: scipy.misc.ascent has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.ascent instead.
#   ascent = misc.ascent()

# %%
ascent.dtype
# Out:
# dtype('int32')

# %%
ascent.shape
# Out:
# (512, 512)

# %%
import scipy.misc

face = scipy.misc.face()
 
print(face.shape)
print(face.max)
print(face.dtype)

plt.axis("off")
plt.gray()
plt.imshow(face)
plt.show()
# Out:
# C:\Users\SOP TELECOM\AppData\Local\Temp\ipykernel_6620\3322926108.py:3: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face = scipy.misc.face()
# (768, 1024, 3)
# <built-in method max of numpy.ndarray object at 0x0000020A92C2F1B0>
# uint8

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc


def tint(imag, percent):
    """imag: the image which will be shaded
    percent: a value between 0 (image will remain unchanged
    and 1 (image will completely white)"""
    tinted_imag = imag + (np.ones(imag.shape)- imag) * percent
    return tinted_imag

face = scipy.misc.ascent() 
tinted_windmills = tint(face, 0)
plt.axis("off")
plt.imshow(tinted_windmills)
# Out:
# C:\Users\SOP TELECOM\AppData\Local\Temp\ipykernel_6620\1557431383.py:13: DeprecationWarning: scipy.misc.ascent has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.ascent instead.
#   face = scipy.misc.ascent()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 charlie = plt.imread('Chaplin.png')
#       3 plt.gray()
#       4 print(charlie)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2195, in imread(fname, format)
#    2193 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2194 def imread(fname, format=None):
# -> 2195     return matplotlib.image.imread(fname, format)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:1563, in imread(fname, format)
#    1556 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1557     # Pillow doesn't handle URLs directly.
#    1558     raise ValueError(
#    1559         "Please open the URL for reading and pass the "
#    1560         "result to Pillow, e.g. with "
# ...
